# %%
#w2a17
print("tam giac sao:")
print("*\n***\n*****")
# Out:
# tam giac sao:
# *
# ***
# *****

# %%
#W2AA6
kytuthuong = input("nhap ky tu: ")
if len(kytuthuong) != 1:
    print("Vui long nhap mot ky tu!")
elif not kytuthuong.islower():
    print("Vui long nhap ky tu thuong!")    
maunicode = ord(kytuthuong)
print("ma unicode cua ky tu",kytuthuong,"la:", maunicode)
kytuinhoa = kytuthuong.upper()
print("ky tu in hoa la:", kytuinhoa)
# Out:
# ma unicode cua ky tu m la: 109
# ky tu in hoa la: M

# %%
#W2AA4
a1,b1,c1,a2,b2,a3 = map(float, input("nhap diem he 10: ").split())
TB = ((a1 + b1 +c1 )+ (a2 +b2)*2 + (a3*3))/10
print("diem trung binh la: ", round(TB,1))
# Out:
# diem trung binh la:  4.2
