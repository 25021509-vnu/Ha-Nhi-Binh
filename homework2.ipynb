# %%
#1
a, b = map(int, input("Chiều dài và chiều rộng (cách nhau bởi dấu cách): ").split())
print("Chu vi hình chữ nhật là", (a + b) * 2)
# Out:
# Chu vi hình chữ nhật là 10

# %%
#2
a = int(input("ban kinh hinh tron la:"))
print("chu vi hinh tron la:", 2*3.14*a)
print("dien tich hinh tron la:", 3.14*a**2)
# Out:
# chu vi hinh tron la: 18.84
# dien tich hinh tron la: 28.26

# %%
#3
a,b,c = map(float, input("nhap 3 canh tam giac").split())
if a + b > c and a + c > b and b + c > a: 
    print("day la 3 canh cua tam giac")
else:
    print("day khong phai 3 canh cua tam giac")
if a == b and a == c and c == b:
    print("tam giac can")
elif a ==b == c:
    print("tam giac deu")
elif a**2 + b**2 == c**2 and a**2 + c**2 == b**2 and b**2 + c**2 == a**2:
    print("tam giac vuong")
else:
    print("tam giac thuong")
# Out:
# day la 3 canh cua tam giac
# tam giac thuong

# %%
#4
a,b = map(float, input("nhap gia tri cua a va b").split())
print(a,"x +",b,"= 0")
print("nghiem cua phuong trinh la:", -b/a)
# Out:
# 2.0 x + 3.0 = 0
# nghiem cua phuong trinh la: -1.5
